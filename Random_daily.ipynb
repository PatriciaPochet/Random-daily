# %%
# !pip install colorama

# %%
import random
import time
import colorama
from colorama import Fore
from colorama import Style
import IPython.display as display
from PIL import Image

# %%
data_blue = {'ANDREI':{'intro':["Un accent charmant, un sens du service à toute épreuve", "De loin, le plus sérieux d'entre nous ...", 
                                "A-t-il finalement fait une pause pendant ces vacances ?", 
                                "C'est ce que nous lui demanderons dans un instant à notre valeureux ..."], 'color': None}, 
             'ANTONY': {'intro':["Dash, crypto ...", "2 mots, même pas 3 et c'est déjà le bingo !", "Dash, crypto, music addict mais pas que", 
                                 "Bienvenue à notre incontournable ... "], 'color': None},
             'AUDREY': {'intro':["Notre Pink Lady de l'auto-dérision", "La duchesse des petits rires gracieux", 
                                 "Passionnée de l'analyse en chimie comme en data", "Au tour de notre invraisemblable ..."], 'color': Fore.MAGENTA},   
             'BENOIT C': {'intro':["Le roi du mystère se dévoilant uniquement sur Mac", "Le soldat victorieux des tests interminables",
                                   "Le prince des daily succincts", "Nous suprendra-t-il cette fois ? Place à notre incomparable ..."], 'color': None},
             'BENOIT R': {'intro':["Le guitariste soliste de l'éloquence", "Le rocker de l'ambition et de l'efficacité", 
                                   "Le team player qui sait jouer sa partition", "La scène et le micro sont à toi, inimitable ..."], 'color': Fore.RED},
             'CATHERINE': {'intro':["Elle excelle en statistiques et SQL", "A le sens de l'exploration du haut de sa mindmap",
                                    "Parle haut et fort si elle le juge bon pour elle ou pour vous ...", "La voici, l'inoubliable ..."], 'color': None},
             'CHRISTIAN': {'intro': ["Toujours prêt à tester les derniers outils", "Tu peines à savoir à quel groupe tu appartiens ...", 
                                     "... qu'il dégaîne déjà l'invitation discord", "C'est au tour du Lucky Luke du deepnote ... l'imparable ..."], 'color': None},
             'CLARISSE': {'intro':["L'Europe est son terrain de jeu familial", "L'enthousiasme, son maître mot", "Le soleil lui prête ses reflets dorés",
                                   "Laissons la parole à la lumineuse ..."], 'color': Fore.YELLOW},
             'EMILIE': {'intro':["La princesse de la mesure et de l'organisation", "Concise, elle manie la prise de notes comme personne",
                                 "Tu as à peine besoin de qqch qu'elle est déjà sur le coup notre dame de coeur", 
                                 "Rien que pour vous, l'adorable ..."], 'color': None},
             'GERMAIN': {'intro': ["Le défenseur de la culture en général,", "Le justicier des mots méconnus comme l'esperluète ...",
                                  "Ou esperluette, aussi appelée perluète, perluette ou juste ... 'et' ... le croyez-vous ?", "Mais aussi humoriste au grand coeur",
                                  "Laissons la place à notre très affable ..."], 'color': None},
             'GUILLAUME': {'intro':["L'accent toujours chantant", "Le sourire et le rire jamais loin", "Il a la curiosité du qui, du quoi comme de tout",
                                  "C'est à ton tour notre chaleureux ..."], 'color': None},
             'LAETITIA': {'intro':["Petite fée de la créativité", "Voyageuse intrépide, elle sait garder son cap qu'elle préfèrera toujours vert",
                                 "Maîtresse d'école, elle sait nous rappeler les signatures mais surtout les récrés et les week-ends",
                                 "La classe est à toi, vénérable ..."], 'color': Fore.GREEN},
              'MARIE': {'intro':["Brunette malicieuse, souriante discrète, technicienne première classe", "Le lundi ne sera jamais son jour favori", 
                                 "Elle nous l'a bien souvent dit", "Bienvenue à notre insondable ..."], 'color': None},
             'PATRICIA': {'intro':["Côte d'azur, Côte émeraude, costa brava, costa del sol, ...", "Toutes la font rêver mais une seule a son coeur ...",
                                 "à la fille de la Côte d'Opale", "A toi, donc la parole ..."], 'color': None},
             'YANNICK': {'intro':["Les doigts sur le clavier", "Les yeux sur l'écran", "L'esprit dans son code", 
                                  "Le roi de la concentration envers et contre tout et tous", "Nous accueillons notre inclassable ..."], 'color': None}
             }

# %%
def random_daily():
    colors = [Fore.BLUE, Fore.YELLOW, Fore.RED, Fore.GREEN, Fore.MAGENTA]
    students = list(data_blue.keys())       # students name list
    students_already_cited = []             # list to store students already cited 
    yes = ['oui', 'ouais', 'yep', 'yes']    # confirmation list for the answer to "ready to go?"
    ok = ['ok', 'parfait', 'ok, impec !', 'ok, top !', "ok, let's go!"]  # answers list to print after confirmation
    display.display(Image.open('/content/happy_ny.jpg'))   # display happy new year image 
    print()
    time.sleep(5)
    print('Une excellente nouvelle année à tous pleine de surprises, de succès et de rires !')
    time.sleep(2)
    print('Eh oui ! il en fallait un ... le 3ème module random créé pour le daily est un module python ! :-)')
    time.sleep(2)
    print("So let's go! Et place à la technique !")
    time.sleep(2)
    print()
    input('On lance le premier daily de 2022 ? ')       # to be able to decide when we launch the nomination
    print()
    previous_color = ''        # to deal with color change for each student
    while len(students_already_cited) != len(students):
        student = random.choice(students)    
        if data_blue[student]['color'] == None:
            color = random.choice(colors)
        else:
            color = data_blue[student]['color']    # for some students, I want a color to be used
        if student not in students_already_cited and (color != previous_color or data_blue[student]['color'] != None):
        # conditions : students not already cited for the daily, color different from the previous student except if 
        # it is a student for which I want a precise color to match the text 
            for loop in range(len(data_blue[student]['intro'])):
                print(color + data_blue[student]['intro'][loop] + Style.RESET_ALL)  # to print the text with color chosen
                time.sleep(3)
            print()   
            print(color + student.center(30, '*') + Style.RESET_ALL)    # to print the student name always at the same place with * before and after
            print()
            confirmation = input('Ready to go? ')   # if ok we have to choose a confirmation in the list 
            if confirmation in yes:       # if student is there and ready to take his turn
                students_already_cited.append(student)
                previous_color = color    # to deal with color condition 
                print(random.choice(ok))  # to print an answer to the confirmation
                time.sleep(90)            # to give time to let the student speak but not too long
                print()
                if len(students_already_cited) == len(students): # to avoid the print of "suivant?" before the end announcement
                    break
                input('Suivant ? ')       # to control the launch of the election of the following student
                print()
            elif confirmation == 'Absent':  # if one of the student is absent that day - Absent with a capital A in case we would written absent for the confirmation for a late student
                students_already_cited.append(student)  # so the student is not cited again
                print("ok, c'est noté ! Suivant donc !")
                print()
            else:
                print("ok partie remise !") # if one of the student is late and has to be cited again
                print()
    # final message to end the random daily program
    print('\nLe tour de table est terminé, chacun de vous a parlé. \nMerci pour votre participation et pour ce daily ! \nExcellente journée à tous !')

# %%
random_daily()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F33D7790290>
# Une excellente nouvelle année à tous pleine de surprises, de succès et de rires !
# Eh oui ! il en fallait un ... le 3ème module random créé pour le daily est un module python ! :-)
# So let's go! Et place à la technique !
#
# On lance le premier daily de 2022 ? oui
#
# Les doigts sur le clavier
# Les yeux sur l'écran
# L'esprit dans son code
# Le roi de la concentration envers et contre tout et tous
# Nous accueillons notre inclassable ...
#
# ***********YANNICK************
#
# Ready to go? oui
# ok, top !
#
# Suivant ? oui
#
# Petite fée de la créativité
# Voyageuse intrépide, elle sait garder son cap qu'elle préfèrera toujours vert
# Maîtresse d'école, elle sait nous rappeler les signatures mais surtout les récrés et les week-ends
# La classe est à toi, vénérable ...
#
# ***********LAETITIA***********
#
# Ready to go? Absent
# ok, c'est noté ! Suivant donc !
#
# ...
